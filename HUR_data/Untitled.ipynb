# %%
import pandas as pd
import reverse_geocoder as rg
import pprint

import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
HUR_data=pd.read_csv('Atlantic-Copy1.csv')
HUR_data.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-3f000359e561> in <module>
# ----> 1 HUR_data=pd.read_csv('Atlantic-Copy1.csv')
#       2 HUR_data.head(3)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
df = pd.DataFrame(HUR_data)
print(df.shape)
print(df.dtypes)

cols = df.columns[:30] # first 30 columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

#df.loc[df['Event']=='L',HUR_data]
   # lats=HUR_data['Latitude'].to_list()
    #lons=HUR_data['Longitude'].to_list()
    #coords=list(zip(lats,lons))

#def reverseGeocode(coords):
 #   result = rg.search(coords)
    
  #  pprint.pprint(result)
# Out:
# (49105, 22)
# ID                  object
# Name                object
# Date                 int64
# Time                 int64
# Event               object
# Status              object
# Latitude            object
# Longitude           object
# Maximum Wind         int64
# Minimum Pressure     int64
# Low Wind NE          int64
# Low Wind SE          int64
# Low Wind SW          int64
# Low Wind NW          int64
# Moderate Wind NE     int64
# Moderate Wind SE     int64
# Moderate Wind SW     int64
# Moderate Wind NW     int64
# High Wind NE         int64
# High Wind SE         int64
# High Wind SW         int64
# High Wind NW         int64
# dtype: object
# <AxesSubplot:>

# %%
# if it's a larger dataset and the visualization takes too long can do this.
# % of missing.
for col in df.columns:
    pct_missing = np.mean(df['Event'].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# ID - 0%
# Name - 0%
# Date - 0%
# Time - 0%
# Event - 0%
# Status - 0%
# Latitude - 0%
# Longitude - 0%
# Maximum Wind - 0%
# Minimum Pressure - 0%
# Low Wind NE - 0%
# Low Wind SE - 0%
# Low Wind SW - 0%
# Low Wind NW - 0%
# Moderate Wind NE - 0%
# Moderate Wind SE - 0%
# Moderate Wind SW - 0%
# Moderate Wind NW - 0%
# High Wind NE - 0%
# High Wind SE - 0%
# High Wind SW - 0%
# High Wind NW - 0%

# %%
# Driver function
#if HUR_data('Event')=="L":
     
    # Coordinates tuple.Can contain more than one pair.
 #   coordinates =(HUR_data['Latitude'],HUR_data['Longitude'])
     
  #  reverseGeocode(coordinates)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-650385516205> in <module>
#       1 # Driver function
# ----> 2 if HUR_data('Event')=="L":
#       3
#       4     # Coordinates tuple.Can contain more than one pair.
#       5     coordinates =(HUR_data['Latitude'],HUR_data['Longitude'])
#
# TypeError: 'DataFrame' object is not callable
