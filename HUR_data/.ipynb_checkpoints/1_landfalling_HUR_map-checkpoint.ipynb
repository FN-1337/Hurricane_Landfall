# %%
# import libraries
import pandas as pd
import panel as pn
pn.extension('plotly')
import plotly.express as px
import hvplot.pandas
import matplotlib.pyplot as plt
import os
from pathlib import Path
from dotenv import load_dotenv

# %%
# Read Mapbox API Key
load_dotenv()
mapbox_api = os.getenv("mapbox")
px.set_mapbox_access_token(mapbox_api)

# %%
from IPython.display import IFrame
IFrame("https://nypost.com/wp-content/uploads/sites/2/2019/08/hurricane-4048.jpg?quality=90&strip=all&w=618&h=410&crop=1", width=900, height=600)
# Out:
#         <iframe
#             width="900"
#             height="600"
#             src="https://nypost.com/wp-content/uploads/sites/2/2019/08/hurricane-4048.jpg?quality=90&strip=all&w=618&h=410&crop=1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Import all hurricane landfalls from the Atlantic basin CSV to Panda Dataframes
file_path = Path("Subset_HURDAT_reverse_geo.csv")
HUR_data = pd.read_csv(file_path)

# %%
# Preview Data
HUR_data.head()
# Out:
#    Unnamed: 0  index        id     name                 date  \
# 0           4      4  AL011851  UNNAMED  1851-06-25 21:00:00
# 1          48     48  AL041851  UNNAMED  1851-08-23 21:00:00
# 2          96     96  AL061851  UNNAMED  1851-10-19 15:00:00
# 3         127    127  AL011852  UNNAMED  1852-08-26 06:00:00
# 4         163    163  AL031852  UNNAMED  1852-09-12 00:00:00
#
#   record_identifier status_of_system  latitude  longitude  \
# 0                 L               HU      28.2      -96.8
# 1                 L               HU      30.1      -85.7
# 2                 L               TS      41.1      -71.7
# 3                 L               HU      30.2      -88.6
# 4                 L               HU      28.0      -82.8
#
#    maximum_sustained_wind_knots  ...  50_kt_ne  50_kt_se  50_kt_sw  50_kt_nw  \
# 0                            80  ...       NaN       NaN       NaN       NaN
# 1                           100  ...       NaN       NaN       NaN       NaN
# ...

# %%
# Florida counties shown with MapBox
fl_county_map = px.scatter_mapbox(HUR_data,
    lat="latitude",
    lon="longitude",
)
fl_county_map.update_layout(mapbox_style="open-street-map")
fl_county_map.show()

# %%
import plotly.graph_objects as go
import Mapbox

#mapbox_access_token = open("pk.eyJ1IjoiYm1kMTIwOSIsImEiOiJja3JvYjZmMXA4Y251MzFvOGVxdm05MXQzIn0.hvANkPpQ0MPJb_RVuncGLg").read()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-a64fb76980b4> in <module>
#       1 import plotly.graph_objects as go
# ----> 2 import Mapbox
#       3
#       4 #mapbox_access_token = open("pk.eyJ1IjoiYm1kMTIwOSIsImEiOiJja3JvYjZmMXA4Y251MzFvOGVxdm05MXQzIn0.hvANkPpQ0MPJb_RVuncGLg").read()
#
# ModuleNotFoundError: No module named 'Mapbox'

# %%
import plotly.express as px
px.set_mapbox_access_token(open(".mapbox_token").read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-c4174dbc78c1> in <module>
#       1 import plotly.express as px
# ----> 2 px.set_mapbox_access_token(open(".mapbox_token").read())
#       3
#
# FileNotFoundError: [Errno 2] No such file or directory: '.mapbox_token'

# %%
file_path = Path("Florida-Median-Prices-Q1-2021.csv")
Price_data = pd.read_csv(file_path)

df = px.data.carshare()
fig = px.scatter_mapbox(df, lat="centroid_lat", lon="centroid_lon",     color="peak_hour", size="car_hours",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=10)
fig.show()
